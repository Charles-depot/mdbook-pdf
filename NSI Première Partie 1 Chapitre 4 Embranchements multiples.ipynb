# %% [markdown]
# <h1 class="alert alert-info"><center>Activité : les embranchements multiples</center></h1>

# %% [markdown]
# <p>Le but de cette activité est de manipuler les structures d'embranchement multiple.</p>

# %% [markdown]
# <h2 class="alert alert-info">Exercice 1 : envoi de courrier</h2>

# %% [markdown]
# La fonction ci-dessous renvoie le prix à payer en euros suivant le poids en grammes de la lettre que l'on veut envoyer.

# %%
def affranchissement(poids):
    if poids <= 20:
        return 1.66
    elif poids <= 100:
        return 2.82
    elif poids <= 250:
        return 4.5
    else:
        return 6.5

# %% [markdown]
# 1. Que renvoient les instructions `affranchissement(15)`, `affranchissement(53)` et `affranchissement(250)` ?

# %% [markdown]
# 2. On désire envoyer une lettre pesant 365 grammes. Quelle instruction doit-on saisir pour connaître le prix à payer ? Quel est ce prix ?

# %% [markdown]
# <p style="font-style:italic; color:gray;">Ecrire la réponse ici</p>

# %% [markdown]
# 3. En fait, la somme de $6,5$ euros n'est valable que pour un poids inférieur ou égal à $500$ grammes. Au delà, il faut payer $8$ euros. <br>Modifier la fonction précédente pour qu'elle prenne en compte cette modification.

# %%
# Ecrire le code de la fonction modifiée ici

# %% [markdown]
# Les cinq cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
affranchissement(10) == 1.66

# %%
affranchissement(70) == 2.82

# %%
affranchissement(190) == 4.5

# %%
affranchissement(380) == 6.5

# %%
affranchissement(501) == 8

# %% [markdown]
# <h2 class="alert alert-info">Exercice 2 : jeu de rôle</h2>

# %% [markdown]
# Dans un jeu de rôle, les joueurs ont un grade dépendant des points d'expérience qu'ils ont acquis.

# %% [markdown]
# ||||||
# | :---- | :----: | :----: |  :----:  |  :----: |
# | Points d'expérience | entre 0 et 99 | entre 100 et 399 | entre 400 et 1499 | supérieur ou égal à 1500 |
# | Grade | padawan | chevalier | maître | grand maître |

# %% [markdown]
# Compléter la fonction suivante de telle sorte qi'elle renvoie le grade d'un joueur en fonction de ses points d'expérience `pointsExp`.

# %%
def grade(pointsExp):
    if pointsExp < ... :
        return 'padawan'
    elif ... :
        return 'chevalier'
    elif ... :
        return ...
    else:
        ...

# %% [markdown]
# Les six cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
grade(15) == 'padawan'

# %%
grade(99) == 'padawan'

# %%
grade(100) == 'chevalier'

# %%
grade(365) == 'chevalier'

# %%
grade(865) == 'maître'

# %%
grade(1500) == 'grand maître'

# %% [markdown]
# <h2 class="alert alert-info">Exercice 3 : intervention d'un technicien</h2>

# %% [markdown]
# Dans le cadre d'un contrat de dépannage, un technicien applique le tarif suivant :
#  - s'il travaille moins de 2h, il applique un forfait de $150$ euros ;
#  - s'il travaille entre 2h et 5h, il ajoute à ce forfait la somme de $40$ euros par heure supplémentaire ;
#  - à partir de 5h de travail, chaque nouvelle heure de travail sera facturée $70$ euros.
#
# En s'aidant de la fonction écrite à l'exercice 6 de l'activité précédente sur les embranchements simples, écrire une fonction `factureIntervention` qui renvoie la facture du technicien suivant son nombre d'heures travaillé. On testera en particulier que le nombre d'heures déclaré est de nature cohérente.

# %%
# Ecrire le code de la fonction ici

# %% [markdown]
# Les cinq cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
factureIntervention(1.75) == 150

# %%
factureIntervention(2) == 150

# %%
factureIntervention(3.5) == 210.0

# %%
factureIntervention(5) == 270

# %%
factureIntervention(7) == 410

# %% [markdown]
# <h2 class="alert alert-info">Exercice 4 : lancer d'un dé truqué</h2>

# %% [markdown]
# On considère un dé à quatre faces numérotées de $1$ à $4$.<br>
# La probabilité d'apparition d'une face est proportionnelle à son numéro.<br>
#
# On lance le dé et on regarde la face obtenue.
#
# Compléter la fonction suivante afin de simuler ce lancer de dé.

# %%
from ... import random
    
def deFaceProportionnelle():
    choixFace = random()
    if choixFace <= ... :
        return 1
    elif choixFace <= 0.3:
        return 2
    elif ... :
        return ...
    else:
        ...

# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Licence Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />Ce document  est mis à disposition selon les termes de la <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Licence Creative Commons Attribution -  Partage dans les Mêmes Conditions 4.0 International</a>.
# Pour toute question : <a href="mailto:charles.poulmaire@ac-versailles.fr">charles.poulmaire@ac-versailles.fr</a> ou <a href="mailto:pascal.remy@ac-versailles.fr">pascal.remy@ac-versailles.fr</a>
