# %% [markdown]
# <h1 class="alert alert-info"><center>Activité : les embranchements simples</center></h1>

# %% [markdown]
# <p>Le but de cette activité est de manipuler les structures d'embranchement simple.</p>

# %% [markdown]
# <h2 class="alert alert-info">Exercice 1 : jeu de rôle</h2>

# %% [markdown]
# Dans un jeu, un joueur dispose de `100` points de vie et d'une défense de `40`.
# Il subit une attaque de valeur `attaque`.
#
# 1. Compléter la fonction suivante renvoyant le nouveau nombre de points de vie du joueur sachant que :
#  - si la valeur de l'attaque est strictement supérieure à celle de la défense, le joueur perd `attaque - 40` points de vie ;
#  - si la valeur de l'attaque est inférieure ou égale à celle de la défense, le joueur ne perd aucun point de vie.

# %%
def attaqueDefense(attaque):
    pointsVie = 100
    if attaque ... :
        return pointVie - ...
    return ...

# %% [markdown]
# Les trois cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
attaqueDefense(110) == 30

# %%
attaqueDefense(20) == 100

# %%
attaqueDefense(40) == 100

# %% [markdown]
# 2. On modifie la fonction précédente en une fonction `pointsVieAttaqueDefense` pour qu'elle fonctionne avec n'importe quel nombre de points de vie, n'importe quelle défense et n'importe quelle attaque en respectant la règle :
#  - si la valeur de l'attaque est strictement supérieure à celle de la défense, le joueur perd `attaque - defense` points de vie ;
#  - si la valeur de l'attaque est inférieure ou égale à celle de la défense, le joueur ne perd aucun point de vie.
#  - si le nouveau nombre de points de vie est strictement négatif, on le ramène à 0.
#
# Compléter cette fonction.

# %%
def pointsVieAttaqueDefense(...,defense,attaque):
    if attaque > defense:
        pointsVie = ...
        if pointsVie < ...:
            pointsVie = ...
    return ...

# %% [markdown]
# Les quatre cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
pointsVieAttaqueDefense(100,40,110) == 30

# %%
pointsVieAttaqueDefense(100,40,20) == 100

# %%
pointsVieAttaqueDefense(100,40,40) == 100

# %%
pointsVieAttaqueDefense(100,40,300) == 0

# %% [markdown]
# <h2 class="alert alert-info">Exercice 2 : maximum et minimum</h2>

# %% [markdown]
# On considère l'algorithme suivant où les paramètres `a` et `b` sont de type numérique (`int` ou `float`) :
#
# ```python
# fonction mystere(a,b)
#     si a > b alors
#         renvoyer a
#     sinon
#         renvoyer b
#     fin si
# fin fonction
# ```
#
# 1. Que renvoient les instructions `mystere(4,2)` et `mystere(-1,0)` ?

# %% [markdown]
# 2. Que renvoie la fonction `mystere` ?

# %% [markdown]
# 3. Modifier cette fonction en une fonction `minimum` pour qu'elle renvoie le minimum des deux valeurs passées en paramètre.

# %% [markdown]
# 4. Implémenter en Python les deux fonctions `mystere` et `minimum`.

# %%
# Ecrire le code de la fonction mystere ici

# %%
# Ecrire le code de la fonction minimum ici

# %% [markdown]
# Les quatre cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
mystere(4,2) == 4

# %%
mystere(-1,0) == 0

# %%
minimum(4,2) == 2

# %%
minimum(-1,0) == -1

# %% [markdown]
# <h2 class="alert alert-info">Exercice 3 : tirage photos</h2>

# %% [markdown]
# Un photographe propose le tirage de photos numériques au tarif de $0,16$ euro l'unité. Le tarif devient de $0,12$ euro l'unité pour une commande d'au moins $75$ photos.
#
# Compléter le code de la fonction suivante afin qu'elle renvoie le montant à payer en fonction du nombre de photos que l'on souhaite tirer.

# %%
def prixDeveloppement(nbPhotos):
    if nbPhotos ... :
        return nbPhotos*0.16
    else:
        return ...

# %% [markdown]
# Les trois cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
prixDeveloppement(10) == 1.6

# %%
prixDeveloppement(75) == 9.0

# %%
prixDeveloppement(80) == 9.6

# %% [markdown]
# <h2 class="alert alert-info">Exercice 4 : reprographie</h2>

# %% [markdown]
# Un commerce de reprographie facture $0,20$ euro l'unité les $20$ premières photocopies et $0,10$ euro l'unité les suivantes.
#
# En s'aidant de la fonction écrite à l'exercice 3, écrire une fonction `prixReprographie` prenant en paramètre les nombres de photocopies à réaliser et renvoyant le prix à payer.

# %%
# Ecrire le code de la fonction ici

# %% [markdown]
# Les quatre cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
prixReprographie(15) == 3.0

# %%
prixReprographie(20) == 4.0

# %%
prixReprographie(21) == 4.1

# %%
prixReprographie(30) == 5.0

# %% [markdown]
# <h2 class="alert alert-info">Exercice 5 : suite de Syracuse (partie 1)</h2>

# %% [markdown]
# On considère une fonction `syracuse` qui prend en paramètre un entier $n$ supérieur ou égal à $1$ et qui renvoie un nombre entier égal à la valeur de $n/2$ si $n$ est pair et à la valeur de $3n+1$ si $n$ est impair.
#
# 1. Compléter le code de cette fonction :

# %%
def syracuse(n):
    if ... :
        return ...
    else:
        return 3*n + 1

# %% [markdown]
# 2. Que renvoient les instructions `syracuse(0)`, `syracuse(-5)` et `syracuse('A')` ? Est-ce cohérent avec l'énoncé ?

# %%
# Tester les appels ici

# %% [markdown]
# 3. Compléter le code de la fonction ci-dessous afin qu'elle vérifie à la première ligne grâce à un test d'assertion que les données passées en paramètre sont bien des entiers supérieurs ou égaux à $1$.

# %%
def syracuse(n):
    assert ... and ...
    if ... :
        return ...
    else:
        return 3*n + 1

# %%
# Tester à nouveaux les appels ici

# %% [markdown]
# <h2 class="alert alert-info">Exercice 6 : intervention d'un technicien</h2>

# %% [markdown]
# Dans le cadre d'un contrat de dépannage, un technicien applique le tarif suivant :
#  - s'il travaille moins de 2h, il applique un forfait de $150$ euros ;
#  - s'il travaille plus de 2h, il ajoute à ce forfait la somme de $40$ euros par heure supplémentaire.
#
# Compléter le code de la fonction suivante afin qu'elle renvoie la facture du technicien suivant son nombre d'heures travaillé. On testera en particulier que le nombre d'heures déclaré est de nature cohérente.

# %%
def factureIntervention(...):
    assert ...
    if nbHeures ... :
        return 150
    else:
        return ...

# %% [markdown]
# Les quatre cellules suivantes permettent de tester votre fonction. Elles doivent renvoyer `True` lors de leur exécution.

# %%
factureIntervention(1.5) == 150

# %%
factureIntervention(2) == 150

# %%
factureIntervention(2.5) == 170.0

# %%
factureIntervention(4) == 230

# %% [markdown]
# <h2 class="alert alert-info">Exercice 7 : pile ou face</h2>

# %% [markdown]
# Compléter la fonction suivante afin de simuler le jeu du Pile ou Face avec une pièce équilibrée.

# %%
from random ... randint
    
def pileOuFace():
    alea = randint(0,...)
    if ... == 0:
        return 'Pile'
    else:
        return ...

# %% [markdown]
# <h2 class="alert alert-info">Exercice 8 : tirage dans une urne</h2>

# %% [markdown]
# Une urne contient trois boules rouges et quatre boules bleues indiscernables au toucher.<br>
# On tire au hasard une boule de l'urne et on regarde sa couleur.
#
# Compléter la fonction suivante afin de simuler cette expérience.

# %%
from ...

def tirageUrne():
    choixBoule = randint(1,7)
    if ... :
        return 'rouge'
    return ...

# %% [markdown]
# <h2 class="alert alert-info">Exercice 9 : tirage dans deux urnes</h2>

# %% [markdown]
# On considère deux urnes :
#  - la première contient quatre boules rouges et deux boules bleues indiscernables au toucher ;
#  - la seconde contient cinq boules rouges au quatre boules bleues indiscernables au toucher.
#
# On choisit une urne au hasard, puis on tire au hasard une boule de cette dernière et on regarde sa couleur.
#
# En s'aidant de la fonction écrite à l'exercice 7, compléter la fonction suivante afin de simuler cette expérience.

# %%
...
    
def tirageDeuxUrnes():
    choixUrne = randint(1,2)
    if choixUrne == 1: # choix de l'urne 1
        # à compléter, éventuellement sur plusieurs lignes
    else: # choix de l'urne 2
        # à compléter, éventuellement sur plusieurs lignes

# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Licence Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />Ce document  est mis à disposition selon les termes de la <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Licence Creative Commons Attribution -  Partage dans les Mêmes Conditions 4.0 International</a>.
# Pour toute question : <a href="mailto:charles.poulmaire@ac-versailles.fr">charles.poulmaire@ac-versailles.fr</a> ou <a href="mailto:pascal.remy@ac-versailles.fr">pascal.remy@ac-versailles.fr</a>
