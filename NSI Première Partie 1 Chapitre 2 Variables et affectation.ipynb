# %% [markdown]
# <h1 class="alert alert-info"><center>Activité : variables et affectation</center></h1>

# %% [markdown]
# <b>Le bouton Exécuter (ou Run) permet de faire tourner le code écrit dans la zone (c'est équivalent au raccourci clavier Ctrl+Entrée)</b>.
# ![bt1.PNG](attachment:bt1.PNG)

# %% [markdown]
# <p>Le but de cette activité est de manipuler les variables et les affectations.</p>

# %% [markdown]
# <h2 class="alert alert-info">Exercice 1 : implémentation</h2>

# %% [markdown]
# On considère l'algorithme suivant :<br/><br/>
# <code>a</code> $\leftarrow$ <code>5</code><br/>
# <code>b</code> $\leftarrow$ <code>a - 4</code><br/>
# <code>a</code> $\leftarrow$ <code>a + b - 3</code><br/>
# <code>b</code> $\leftarrow$ <code>a + 3</code><br/>
# <br/><br/>
# <ol>
#     <li>Implémenter ci-dessous cet algorithme en langage Python.</li>
#     </ol>

# %%
# Ecrire les instructions ici

# %% [markdown]
# <ol start='2'>
#     <li>Que contiennent les deux variables <code>a</code> et <code>b</code> à l’issue de l’algorithme ?</li>
#     </ol>

# %% [markdown]
# <p style="font-style:italic; color:gray;">Ecrire la réponse ici</p>

# %% [markdown]
# <h2 class="alert alert-info">Exercice 2 : modification de contenu</h2>

# %% [markdown]
# <ol>
#     <li>Taper dans la  cellule code ci-dessous les instructions suivantes puis exécuter la cellule.</li>
#     </ol>
#
# ```python
# point_de_vie = 55
# degats = 20
# point_de_vie = point_de_vie - degats```

# %%
# Ecrire les instructions ici

# %% [markdown]
# <ol start='2'>
#     <li>Quelle est la valeur de la variable <code>point_de_vie</code> à la fin de l'exécution des ces trois instructions ?</li>
#     </ol>

# %% [markdown]
# <p style="font-style:italic; color:gray;">Ecrire la réponse ici</p>

# %% [markdown]
# <h2 class="alert alert-info">Exercice 3 : fonction <code>print</code></h2>

# %% [markdown]
# <ol>
#     <li>Ecrire ci-dessous une instruction permettant d'affecter à une variable <code>x</code> la valeur 3.</li>
# </ol>

# %%
# Ecrire l'instruction Python ici

# %% [markdown]
# <ol start='2'>
#     <li> Compléter le code suivant afin d'affecter à la variable <code>y</code> la valeur de <code>x + 9</code>.</li>
# </ol>

# %%
y = ... # à compléter

# %% [markdown]
# <ol start='3'>
#     <li> Quelle valeur contient alors la variable <code>y</code> ?</li>
# </ol>

# %% [markdown]
# <p style="font-style:italic; color:gray;">Ecrire la réponse ici</p>

# %% [markdown]
# <ol start='4'>
#     <li>La fonction <code>print</code> permet d'afficher le contenu d'une variable.
#     <br/>
#     Exécuter la cellule suivante pour vérifier la réponse de la question précédente.</li>
#     </ol>

# %%
print(y)

# %% [markdown]
# <ol start='5'>
#     <li>Modifier la valeur 3 par la valeur 5 dans la cellule de la question 1 et exécuter à nouveau toutes les cellules suivantes.<br/>
#         La valeur affichée lors de l'instruction <code>print(y)</code> est-elle correcte ?</li>
#     </ol>

# %% [markdown]
# <h2 class="alert alert-info">Exercice 4 : quel affichage ?</h2>

# %% [markdown]
# On exécute la séquence suivante :
# ```python
# x = 5
# y = x + 1
# x = 10
# print(y)
# ```
# Produit-elle l'affichage de la valeur 6 ou de la valeur 11 ?
# </div>

# %% [markdown]
# <h2 class="alert alert-info">Exercice 5 : opérations</h2>

# %% [markdown]
# <ol>
#     <li>Compléter les deux lignes du code ci-dessous afin d'afficher le contenu de la variable <code>y</code> qui prend la valeur <code>3x<sup>2</sup>+5x-7</code>.</li>
#     </ol>

# %%
x = 3
y = ... # à compléter
... # à compléter

# %% [markdown]
# <ol start='2'>
#     <li>Quel est l'intérêt d'écrire la variable <code>y</code> en fonction de la variable <code>x</code> et non d'écrire directement la valeur voulue pour <code>y</code> ?</li>
#     </ol>

# %% [markdown]
# <p style="font-style:italic; color:gray;">Ecrire la réponse ici</p>

# %% [markdown]
# <h2 class="alert alert-info">Exercice 6 : fonction <code>input</code></h2>

# %% [markdown]
# <ol>
#     <li>La fonction <code>input</code> permet de demander à l'utilisateur de saisir des données au clavier.<br/>
#         Tester le code suivant.</li>
#     </ol>

# %%
a = int(input("Saisir un nombre entier : "))
print(a)

# %% [markdown]
# <p style="color:rgb(255,0,0)">A retenir</p>
# <div class="alert alert-danger" style="border-left: 15px solid #a94442;border-radius:2px;">
# La fonction <code>input</code> renvoie la saisie de l'utilisateur sous la forme d'une chaîne de caractères (c'est-à-dire du texte) et la fonction <code>int</code> permet de l' &lsaquo;&lsaquo; interpréter &rsaquo;&rsaquo; comme un nombre entier.
# </div>

# %% [markdown]
# <ol start='2'>
#     <li>Compléter le code suivant pour afficher le contenu de la variable <code>y</code> qui prend la valeur du quotient <code>(2x-3)/(x-3)</code>.</li>
#     </ol>

# %%
x = int(input("Saisir un nombre entier : "))
y = ... # à compléter
... # à compléter

# %% [markdown]
# <ol start='3'>
#     <li>Exécuter cette cellule quatre fois en saisissant successivement les valeurs 4, 5, 6 et 3 pour <code>x</code>.
#         <br/>
#         Que remarque-t-on ?</li>
#     </ol>

# %% [markdown]
# <h2 class="alert alert-info">Exercice 7 : fonction <code>del</code></h2>

# %% [markdown]
# <ol>
#     <li>Exécuter la cellule suivante :</li>
#     </ol>

# %%
a = 3
b = a - 5
print('a =',a)
print('b =',b)

# %% [markdown]
# <ol start='2'>
#     <li>Exécuter la cellule suivante :</li>
#     </ol>

# %%
del(a)
print(a)

# %% [markdown]
# <ol start='3'>
# <li>A quoi sert la fonction <code>del</code> ?</li>
# </ol>

# %% [markdown]
# <ol start='4'>
#     <li>Exécuter la cellule ci-dessous. La réponse obtenue est-elle cohérente avec les instructions des questions 1 et 2 ?</li>
#     </ol>

# %%
print(b)

# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Licence Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />Ce document  est mis à disposition selon les termes de la <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Licence Creative Commons Attribution -  Partage dans les Mêmes Conditions 4.0 International</a>.
# Pour toute question : <a href="mailto:charles.poulmaire@ac-versailles.fr">charles.poulmaire@ac-versailles.fr</a> ou <a href="mailto:pascal.remy@ac-versailles.fr">pascal.remy@ac-versailles.fr</a>
